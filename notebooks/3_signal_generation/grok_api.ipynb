# %%
import os
import json

from dotenv import load_dotenv
from openai import OpenAI

from utils.datapath import get_random_pdf_pair, get_all_pdfs
from utils.pdf import extract_pdf_text
from utils.llm_api import call_grok_api, prepare_prompt_messages

# %%
# TODO:

# Get forecast for company from API
# 1. Get pair of pdfs - DONE
# 2. Extract text from pdf - DONE
# 3. Chunk text to max token size - NOT NECESSARY
# 4. Create summarize function (should have prompt to make it so that the company cannot be distinguished) - DONE (Partial)
# 5. Create compare prompt - DONE
# 6. Compare the companies and find which is better - DONE

# %%
load_dotenv()
XAI_API_KEY = os.getenv("XAI_API_KEY")

client = OpenAI(
    api_key=XAI_API_KEY,
    base_url="https://api.x.ai/v1",
)

# %%
pdf1_path, pdf2_path = get_random_pdf_pair()
pdf1_txt, pdf2_txt = extract_pdf_text(pdf1_path), extract_pdf_text(pdf2_path)

# print(pdf1_txt);
# print(pdf2_txt)

# %%
completion = call_grok_api(client, prepare_prompt_messages(pdf1_txt, pdf2_txt))

# %%
print(completion.choices[0].message.content)
# Out:
# {
#   "winner": 1,
#   "metrics_compared": {
#     "net_sales": {
#       "Company_A": "209,369 million JPY (Q3 2023 cumulative, -16.7% YoY)",
#       "Company_B": "47,305 million JPY (Q1 2023 cumulative, +83.9% YoY)"
#     },
#     "operating_profit": {
#       "Company_A": "-6,546 million JPY (Q3 2023 cumulative, down from 23,254 million JPY YoY)",
#       "Company_B": "10,279 million JPY (Q1 2023 cumulative, +20.8% YoY)"
#     },
#     "net_profit": {
#       "Company_A": "-16,231 million JPY (Q3 2023 cumulative, down from 29,185 million JPY YoY)",
#       "Company_B": "7,702 million JPY (Q1 2023 cumulative, +14.4% YoY)"
#     },
#     "growth_trends": {
#       "Company_A": "Significant decline in sales and profitability due to market challenges",
#       "Company_B": "Strong growth in sales and profitability driven by semiconductor demand"
#     },
#     "equity_ratio": {
#       "Company_A": "68.6% (down from 70.1% YoY)",
#       "Company_B": "41.3% (up from 32.1% YoY)"
#     }
#   },
#   "reasoning": "Company B (Lasertec Corporation) is determined to have performed better than Company A (Nippon Electric Glass Co., Ltd.) based on a comparative analysis of key financial metrics for their respective reporting periods (Q3 2023 cumulative for Company A and Q1 2023 cumulative for Company B). Despite the difference in reporting periods, the analysis focuses on year-over-year (YoY) performance and profitability trends, which provide a clear indication of operational success. Company B reported a substantial increase in net sales (+83.9% YoY to 47,305 million JPY), driven by strong demand in the semiconductor industry, particularly for EUV lithography-related equipment. In contrast, Company A experienced a significant decline in net sales (-16.7% YoY to 209,369 million JPY), attributed to weak demand in key markets such as flat panel displays and glass fiber. On profitability, Company B achieved positive growth in operating profit (+20.8% YoY to 10,279 million JPY) and net profit (+14.4% YoY to 7,702 million JPY), reflecting effective cost management and market positioning. Company A, however, reported substantial losses, with an operating loss of 6,546 million JPY (down from a profit of 23,254 million JPY YoY) and a net loss of 16,231 million JPY (down from a profit of 29,185 million JPY YoY), largely due to cost pressures and business restructuring expenses. Additionally, while Company A's equity ratio remains higher (68.6%) compared to Company B's (41.3%), Company B showed an improvement in financial stability (up from 32.1% YoY), whereas Company A's ratio declined (down from 70.1% YoY). The stark contrast in growth trends and profitability, despite Company A's larger absolute sales figures, underscores Company B's superior performance in a challenging economic environment. Note that the difference in reporting periods (Q3 vs. Q1) is acknowledged as a potential limitation, but the YoY growth metrics provide a consistent basis for comparison, and no assumptions beyond the provided data were necessary."
# }

# %%
response = json.loads(completion.choices[0].message.content)

# %%
response["winner"]
# Out:
# 1

# %%
# TODO:

# 7. Repeat for all quarters and for all company pairs
# 8. Save data to file { quarter: (company1, company2): 0 or 1 ) } where 0 or 1 represents winner
# 9: Create quarterly ranking (Sum points or ELO score)

# %%
# 7. Repeat for all quarters and for all company pairs

# Create loop
len(get_all_pdfs())
# Out:
# 194

# %%
# Docs metadata uses date to query all documents released on that date
# get docs metadata and save it as
# folder: /{quarter}/{date}_{document_name}.pdf

#
